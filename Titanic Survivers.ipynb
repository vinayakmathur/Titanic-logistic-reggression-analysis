# %%
import pandas as pd;

import matplotlib.pyplot  as plt
import seaborn as sns

# %%
test = pd.read_csv('test (2).csv')
train = pd.read_csv('train.csv')

# %%
train['Age'] = train['Age'].fillna(train.Age.median())
test['Age'] =train['Age'].fillna(train.Age.median())
print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             1
# Sex              1
# Age              0
# SibSp            0
# Parch            1
# Ticket           1
# Fare             0
# Cabin          688
# Embarked         3
# dtype: int64
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>892.000000</td>
#       <td>892.000000</td>
#       <td>892.000000</td>
#       <td>892.000000</td>
#       <td>891.000000</td>
#       <td>892.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>0.383408</td>
#       <td>2.309417</td>
#       <td>29.361957</td>
#       <td>0.523009</td>
#       <td>0.381594</td>
#       <td>32.204208</td>
#     </tr>
#     <tr>
#       <th>std</th>
# ...

# %%
fig, ax = plt.subplots(2, 2 , figsize=[10,8])
sns.histplot(data=train,kde=True,x='Age',ax= ax[0,0])
sns.histplot(data=train ,kde=True ,x='Fare',ax= ax[0,1])
sns.histplot(data=train ,kde=True ,x='SibSp',ax= ax[1,0])
sns.histplot(data=train ,kde=True ,x='Parch',ax= ax[1,1])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Count'>

# %%
fig, ax = plt.subplots(2, 2 , figsize=[10,8])
sns.barplot(data=train,x='Sex',y='Survived' ,ax = ax[0,0])
sns.barplot(data=train,x='Embarked',y='Survived' ,ax = ax[0,1])
sns.barplot(data=train,x='Pclass',y='Survived' ,ax = ax[1,0])
sns.barplot(data=train,x='Parch',y='Survived' ,ax = ax[1,1])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Survived'>

# %%
fig,ax = plt.subplots(2,2,figsize=[10,8])
sns.countplot(data=train,x='Sex',hue = 'Survived',ax=ax[0,0])
sns.countplot(data=train,x='Pclass',hue = 'Survived',ax=ax[0,1])
sns.countplot(data=train,x='Embarked',hue = 'Survived',ax=ax[1,0])
sns.countplot(data=train,x='Parch',hue = 'Survived',ax=ax[1,1])
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>
